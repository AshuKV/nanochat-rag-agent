# %% [markdown]
# # LangGraph Components

# %%
import os
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
from langchain_openai import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults
from get_llm import get_llm
from IPython.display import Image, display
from langchain_core.runnables.graph import CurveStyle, MermaidDrawMethod, NodeStyles
# -------------------- REPLACE THE TAVILY API KEY FOR YOURSELF --------------------------
os.environ["TAVILY_API_KEY"] = "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"
# ----------------------------------------------------------------------------------------
# from langchain_ollama import ChatOllama
# local_llm = 'llama3.2:3b-instruct-fp16'
# local_llm = "llama3:latest"

# local_llm = "mistral-nemo:latest"
# llm = ChatOllama(model=local_llm, temperature=0)
# llm_json_mode = ChatOllama(model=local_llm, temperature=0, format='json')

llm = get_llm()
model = llm

# %%
tool = TavilySearchResults(max_results=4) #increased number of results
print("Type of tool: ", type(tool))
print("Tool Name and Description: ", tool.name, ", ", tool.description)
# Out:
# Type of tool:  <class 'langchain_community.tools.tavily_search.tool.TavilySearchResults'>
# Tool Name and Description:  tavily_search_results_json ,  A search engine optimized for comprehensive, accurate, and trusted results. Useful for when you need to answer questions about current events. Input should be a search query.
# C:\Users\ananth\AppData\Local\Temp\ipykernel_19984\4010905469.py:1: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-tavily package and should be used instead. To use it run `pip install -U :class:`~langchain-tavily` and import as `from :class:`~langchain_tavily import TavilySearch``.
#   tool = TavilySearchResults(max_results=4) #increased number of results

# %% [markdown]
# > If you are not familiar with python typing annotation, you can refer to the [python documents](https://docs.python.org/3/library/typing.html).

# %%
class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage], operator.add]

"""
The above is equivalent to:
{
    "messages": []
}
"""
# Out:
# '\nThe above is equivalent to:\n{\n    "messages": []\n}\n'

# %% [markdown]
# > Note: in `take_action` below, some logic was added to cover the case that the LLM returned a non-existent tool name. Even with function calling, LLMs can still occasionally hallucinate. Note that all that is done is instructing the LLM to try again! An advantage of an agentic organization.

# %%
class AgentApp:

    def __init__(self, model, tools, system=""):
        self.system = system
        graph = StateGraph(AgentState)
        graph.add_node("llm", self.call_openai)  # self.call_openai is our execute method
        graph.add_node("action", self.take_action)  # given an action description, perform the action and get the results
        graph.add_conditional_edges(
            "llm",
            self.exists_action,
            {True: "action", False: END}
        )
        graph.add_edge("action", "llm")
        graph.set_entry_point("llm")
        
        self.graph = graph.compile()
        
        self.tools = {t.name: t for t in tools}
        self.model = model.bind_tools(tools)

    def exists_action(self, state: AgentState):
        result = state['messages'][-1]
        result = len(result.tool_calls) > 0
        print("exists_action = ", result)
        return result

    def call_openai(self, state: AgentState):
        messages = state['messages']
        print("messages = ", messages)
        if self.system:
            messages = [SystemMessage(content=self.system)] + messages
        message = self.model.invoke(messages)
        return {'messages': [message]}

    def take_action(self, state: AgentState):
        tool_calls = state['messages'][-1].tool_calls
        results = []
        for t in tool_calls:
            print(f"Calling: {t}")
            if not t['name'] in self.tools:      # check for bad tool name from LLM
                print("\n ....bad tool name....")
                result = "bad tool name, retry"  # instruct LLM to retry if bad
            else:
                result = self.tools[t['name']].invoke(t['args'])
            results.append(ToolMessage(tool_call_id=t['id'], name=t['name'], content=str(result)))
        print("Back to the model!")
        return {'messages': results}

# %%
# prompt = """You are a smart research assistant. Use the search engine to look up information. \
# You are allowed to make multiple calls (either together or in sequence). \
# Only look up information when you are sure of what you want. \
# If you need to look up some information before asking a follow up question, you are allowed to do that!
# """

prompt = """You are a smart research assistant. Answer the query if you know the answer.
If you do not know the answer, use the search engine to look up information. 
You are allowed to make multiple calls (either together or in sequence). 
Only look up information when you are sure of what you want. When you already know the answer, just answer it and do not use the search tool.
For example when you are asked about a future event you can invoke a search tool.
If you need to look up some information before asking a follow up question, you are allowed to do that!
"""

# model = get_llm() #reduce inference cost
abot = AgentApp(model, [tool], system=prompt)
app = abot.graph
display(
    Image(
        app.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
# from IPython.display import Image

# Image(abot.graph.get_graph().draw_png())

# %%
query = "What is NVidia's stock price?"
messages = [HumanMessage(content=query)]
result = abot.graph.invoke({"messages": messages})
# Out:
# messages =  [HumanMessage(content="What is NVidia's stock price?", additional_kwargs={}, response_metadata={})]
# exists_action =  True
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'NVidia stock price'}, 'id': '780946842', 'type': 'tool_call'}
# Back to the model!
# messages =  [HumanMessage(content="What is NVidia's stock price?", additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '780946842', 'function': {'arguments': '{"query":"NVidia stock price"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 41, 'prompt_tokens': 568, 'total_tokens': 609, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'gemma-3-12b-it', 'system_fingerprint': 'gemma-3-12b-it', 'id': 'chatcmpl-j74q7jj3mxstcl3v24jw6', 'service_tier': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--8737617f-f65c-4a06-b1d0-813f6445265f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'NVidia stock price'}, 'id': '780946842', 'type': 'tool_call'}], usage_metadata={'input_tokens': 568, 'output_tokens': 41, 'total_tokens': 609, 'input_token_details': {}, 'output_token_details': {}}), ToolMessage(content="[{'title': 'Stock Quote & Chart - NVIDIA Investor Relations', 'url': 'https://investor.nvidia.com/stock-info/stock-quote-and-chart/default.aspx', 'content': 'XNAS:NVDA,NASD:NVDA historical stock data| Stock Date | Stock Price |\\n --- |\\n| November 04, 2025 | $198.69 |\\n| November 03, 2025 | $206.88 |\\n| October 31, 2025 | $202.49 |\\n| October 30, 2025 | $202.89 |\\n| October 29, 2025 | $207.04 |\\n| October 28, 2025 | $201.03 |\\n| October 27, 2025 | $191.49 |\\n| October 24, 2025 | $186.26 |\\n| October 23, 2025 | $182.16 |\\n| October 22, 2025 | $180.28 |\\n| October 21, 2025 | $181.16 |\\n| October 20, 2025 | $182.64 |\\n| October 17, 2025 | $183.22 | [...] | July 18, 2025 | $172.41 |\\n| July 17, 2025 | $173 |\\n| July 16, 2025 | $171.37 |\\n| July 15, 2025 | $170.7 |\\n| July 14, 2025 | $164.07 |\\n| July 11, 2025 | $164.92 |\\n| July 10, 2025 | $164.1 |\\n| July 09, 2025 | $162.88 |\\n| July 08, 2025 | $160 |\\n| July 07, 2025 | $158.24 |\\n| July 03, 2025 | $159.34 |\\n| July 02, 2025 | $157.25 |\\n| July 01, 2025 | $153.3 |\\n| June 30, 2025 | $157.99 |\\n| June 27, 2025 | $157.75 |\\n| June 26, 2025 | $155.02 |\\n| June 25, 2025 | $154.31 |\\n| June 24, 2025 | $147.9 | [...] | October 16, 2025 | $181.81 |\\n| October 15, 2025 | $179.83 |\\n| October 14, 2025 | $180.03 |\\n| October 13, 2025 | $188.32 |\\n| October 10, 2025 | $183.16 |\\n| October 09, 2025 | $192.57 |\\n| October 08, 2025 | $189.11 |\\n| October 07, 2025 | $185.04 |\\n| October 06, 2025 | $185.54 |\\n| October 03, 2025 | $187.62 |\\n| October 02, 2025 | $188.89 |\\n| October 01, 2025 | $187.24 |\\n| September 30, 2025 | $186.58 |\\n| September 29, 2025 | $181.85 |\\n| September 26, 2025 | $178.19 |', 'score': 0.9307171}, {'title': 'NVIDIA - 26 Year Stock Price History | NVDA - Macrotrends', 'url': 'https://www.macrotrends.net/stocks/charts/NVDA/nvidia/stock-price-history', 'content': 'Historical daily share price chart and data for NVIDIA since 1999 adjusted for splits and dividends. The latest closing stock price for NVIDIA as of November 04, 2025 is 198.69. \\n   The all-time high NVIDIA stock closing price was 207.04 on October 29, 2025.\\n   The NVIDIA 52-week high stock price is 212.19, which is 6.8% above the current share price.\\n   The NVIDIA 52-week low stock price is 86.62, which is 56.4% below the current share price. [...] The average NVIDIA stock price for the last 52 weeks is 147.06.', 'score': 0.92715925}, {'title': 'NVIDIA Corporation (NVDA) Stock Historical Prices & Data', 'url': 'https://finance.yahoo.com/quote/NVDA/history/', 'content': '| Date | Open | High | Low | Close Close price adjusted for splits. | Adj Close Adjusted close price adjusted for splits and dividend and/or capital gain distributions. | Volume |\\n ---  ---  --- \\n| Nov 4, 2025 | 202.95 | 203.97 | 197.93 | 198.69 | 198.69 | 185,783,248 |\\n| Nov 3, 2025 | 208.08 | 211.34 | 205.56 | 206.88 | 206.88 | 180,267,300 |\\n| Oct 31, 2025 | 206.45 | 207.97 | 202.07 ...
# exists_action =  False

# %%
result
# Out:
# {'messages': [HumanMessage(content="What is NVidia's stock price?", additional_kwargs={}, response_metadata={}),
#   AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '780946842', 'function': {'arguments': '{"query":"NVidia stock price"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 41, 'prompt_tokens': 568, 'total_tokens': 609, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'gemma-3-12b-it', 'system_fingerprint': 'gemma-3-12b-it', 'id': 'chatcmpl-j74q7jj3mxstcl3v24jw6', 'service_tier': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--8737617f-f65c-4a06-b1d0-813f6445265f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'NVidia stock price'}, 'id': '780946842', 'type': 'tool_call'}], usage_metadata={'input_tokens': 568, 'output_tokens': 41, 'total_tokens': 609, 'input_token_details': {}, 'output_token_details': {}}),
#   ToolMessage(content="[{'title': 'Stock Quote & Chart - NVIDIA Investor Relations', 'url': 'https://investor.nvidia.com/stock-info/stock-quote-and-chart/default.aspx', 'content': 'XNAS:NVDA,NASD:NVDA historical stock data| Stock Date | Stock Price |\\n --- |\\n| November 04, 2025 | $198.69 |\\n| November 03, 2025 | $206.88 |\\n| October 31, 2025 | $202.49 |\\n| October 30, 2025 | $202.89 |\\n| October 29, 2025 | $207.04 |\\n| October 28, 2025 | $201.03 |\\n| October 27, 2025 | $191.49 |\\n| October 24, 2025 | $186.26 |\\n| October 23, 2025 | $182.16 |\\n| October 22, 2025 | $180.28 |\\n| October 21, 2025 | $181.16 |\\n| October 20, 2025 | $182.64 |\\n| October 17, 2025 | $183.22 | [...] | July 18, 2025 | $172.41 |\\n| July 17, 2025 | $173 |\\n| July 16, 2025 | $171.37 |\\n| July 15, 2025 | $170.7 |\\n| July 14, 2025 | $164.07 |\\n| July 11, 2025 | $164.92 |\\n| July 10, 2025 | $164.1 |\\n| July 09, 2025 | $162.88 |\\n| July 08, 2025 | $160 |\\n| July 07, 2025 | $158.24 |\\n| July 03, 2025 | $159.34 |\\n| July 02, 2025 | $157.25 |\\n| July 01, 2025 | $153.3 |\\n| June 30, 2025 | $157.99 |\\n| June 27, 2025 | $157.75 |\\n| June 26, 2025 | $155.02 |\\n| June 25, 2025 | $154.31 |\\n| June 24, 2025 | $147.9 | [...] | October 16, 2025 | $181.81 |\\n| October 15, 2025 | $179.83 |\\n| October 14, 2025 | $180.03 |\\n| October 13, 2025 | $188.32 |\\n| October 10, 2025 | $183.16 |\\n| October 09, 2025 | $192.57 |\\n| October 08, 2025 | $189.11 |\\n| October 07, 2025 | $185.04 |\\n| October 06, 2025 | $185.54 |\\n| October 03, 2025 | $187.62 |\\n| October 02, 2025 | $188.89 |\\n| October 01, 2025 | $187.24 |\\n| September 30, 2025 | $186.58 |\\n| September 29, 2025 | $181.85 |\\n| September 26, 2025 | $178.19 |', 'score': 0.9307171}, {'title': 'NVIDIA - 26 Year Stock Price History | NVDA - Macrotrends', 'url': 'https://www.macrotrends.net/stocks/charts/NVDA/nvidia/stock-price-history', 'content': 'Historical daily share price chart and data for NVIDIA since 1999 adjusted for splits and dividends. The latest closing stock price for NVIDIA as of November 04, 2025 is 198.69. \\n   The all-time high NVIDIA stock closing price was 207.04 on October 29, 2025.\\n   The NVIDIA 52-week high stock price is 212.19, which is 6.8% above the current share price.\\n   The NVIDIA 52-week low stock price is 86.62, which is 56.4% below the current share price. [...] The average NVIDIA stock price for the last 52 weeks is 147.06.', 'score': 0.92715925}, {'title': 'NVIDIA Corporation (NVDA) Stock Historical Prices & Data', 'url': 'https://finance.yahoo.com/quote/NVDA/history/', 'content': '| Date | Open | High | Low | Close Close price adjusted for splits. | Adj Close Adjusted close price adjusted for splits and dividend and/or capital gain distributions. | Volume |\\n ---  ---  --- \\n| Nov 4, 2025 | 202.95 | 203.97 | 197.93 | 198.69 | 198.69 | 185,783,248 |\\n| Nov 3, 2025 | 208.08 | 211.34 | 205.56 | 206.88 | 206.88 | 180,267,300 |\\n| Oct 31, 2025 | 206.45 | 207.97 | 202.07 | 202.49 | 202.49 | 179,802,200 |\\n| Oct 30, 2025 | 205.15 | 206.16 | 201.41 | 202.89 | 202.89 | 178,864,400 | [...] | Oct 13, 2025 | 187.97 | 190.11 | 185.96 | 188.32 | 188.32 | 153,482,800 |\\n| Oct 10, 2025 | 193.51 | 195.62 | 182.05 | 183.16 | 183.16 | 268,774,400 |\\n| Oct 9, 2025 | 192.23 | 195.30 | 191.06 | 192.57 | 192.57 | 182,997,200 |\\n| Oct 8, 2025 | 186.57 | 189.60 | 186.54 | 189.11 | 189.11 | 130,168,900 |\\n| Oct 7, 2025 | 186.23 | 189.06 | 184.00 | 185.04 | 185.04 | 140,088,000 |\\n| Oct 6, 2025 | 185.50 | 187.23 | 183.33 | 185.54 | 185.54 | 157,678,100 | [...] | Oct 29, 2025 | 207.98 | 212.19 | 204.78 | 207.04 | 207.04 | 308,829,600 |\\n| Oct 28, 2025 | 193.05 | 203.15 | 191.91 | 201.03 | 201.03 | 297,986,200 |\\n| Oct 27, 2025 | 189.99 | 192.00 | 188.43 | 191.49 | 191.49 | 153,452,700 |\\n| Oct 24, 2025 | 183.84 | 187.47 | 183.50 | 186.26 | 186.26 | 131,296,700 |\\n| Oct 23, 2025 | 180.42 | 183.03 | 179.79 | 182.16 | 182.16 | 111,363,700 |\\n| Oct 22, 2025 | 181.1 ...
#   AIMessage(content="As of November 4, 2025, NVidia's stock price is approximately $198.69.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 29, 'prompt_tokens': 4058, 'total_tokens': 4087, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'gemma-3-12b-it', 'system_fingerprint': 'gemma-3-12b-it', 'id': 'chatcmpl-t08cgur767i28zll0kjade', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--6275deb8-5b8a-4a61-827f-d0b9faa119dd-0', usage_metadata={'input_tokens': 4058, 'output_tokens': 29, 'total_tokens': 4087, 'input_token_details': {}, 'output_token_details': {}})]}

# %%
result['messages'][-1].content
# Out:
# "As of November 4, 2025, NVidia's stock price is approximately $198.69."

# %%
messages = [HumanMessage(content="Is NVidia more valued than Microsoft?")]
result = abot.graph.invoke({"messages": messages})
# Out:
# messages =  [HumanMessage(content='Is NVidia more valued than Microsoft?', additional_kwargs={}, response_metadata={})]
# exists_action =  True
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'nvidia vs microsoft market cap'}, 'id': '668552358', 'type': 'tool_call'}
# Back to the model!
# messages =  [HumanMessage(content='Is NVidia more valued than Microsoft?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '668552358', 'function': {'arguments': '{"query":"nvidia vs microsoft market cap"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 41, 'prompt_tokens': 567, 'total_tokens': 608, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'gemma-3-12b-it', 'system_fingerprint': 'gemma-3-12b-it', 'id': 'chatcmpl-93qzzd0e93y7olbzpbq0s', 'service_tier': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--216961bd-3f93-43bf-bef9-e56b79622b06-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'nvidia vs microsoft market cap'}, 'id': '668552358', 'type': 'tool_call'}], usage_metadata={'input_tokens': 567, 'output_tokens': 41, 'total_tokens': 608, 'input_token_details': {}, 'output_token_details': {}}), ToolMessage(content='[{\'title\': \'NVIDIA (NVDA) - Market capitalization - Companies Market Cap\', \'url\': \'https://companiesmarketcap.com/nvidia/marketcap/\', \'content\': "| Name | Marketcap | Market cap differencediff. | Country |\\n ---  --- |\\n| Texas Instruments  TXN | $146.35 B | -97.14% | 🇺🇸 USA |\\n| AMD  AMD | $418.19 B | -91.82% | 🇺🇸 USA |\\n| Intel  INTC | $189.47 B | -96.29% | 🇺🇸 USA |\\n| QUALCOMM  QCOM | $193.69 B | -96.21% | 🇺🇸 USA |\\n| STMicroelectronics  STM | $22.12 B | -99.57% | 🇨🇭 Switzerland |\\n| Microsoft  MSFT | $3.856 T | -24.59% | 🇺🇸 USA |\\n| Cambricon Technologies  688256.SS | $79.73 B | -98.44% | 🇨🇳 China | [...] ## End of Day market cap according to different sources\\n\\nOn Nov 2nd, 2025 the market cap of NVIDIA was reported to be:\\n\\n$4.920 Trillion USD\\n\\nby Nasdaq\\n\\n$4.930 Trillion USD\\n\\nby CompaniesMarketCap\\n\\n### Market capitalization for similar companies or competitors [...] As of November 2025 NVIDIA has a market cap of $5.113 Trillion USD. This makes NVIDIA the world\'s most valuable company by market cap according to our data. The market capitalization, commonly called market cap, is the total market value of a publicly traded company\'s outstanding shares and is commonly used to measure how much a company is worth.\\n\\n## Market cap history of NVIDIA from 1999 to 2025\\n\\n### End of year Market Cap", \'score\': 0.7927375}, {\'title\': \'Nvidia - Wikipedia\', \'url\': \'https://en.wikipedia.org/wiki/Nvidia\', \'content\': \'On March 1, 2024, Nvidia became the third company in the history of the United States to close with a market capitalization in excess of $2 trillion.( Nvidia needed only 180 days to get to $2 trillion from $1 trillion, while the first two companies, Apple and Microsoft, each took over 500 days.( On March 18, Nvidia announced its new AI chip and microarchitecture Blackwell "Blackwell (microarchitecture)"), named after mathematician David Blackwell.( [...] The company became the world\\\'s most valuable, surpassing Microsoft and Apple, on June 18, 2024, after its market capitalization exceeded $3.3 trillion.( [...] In July 2025, it was announced that Nvidia had acquired CentL, a Canadian-based AI firm.(\\n\\nOn July 10, 2025, Nvidia closed for the first time with a market cap above $4 trillion, after its market cap briefly touched and then retreated from that number during the previous day.( Nvidia became the first company to reach a market cap of $4 trillion.( At that point, Nvidia was worth more than the combined value of all publicly traded companies in the United Kingdom.(\', \'score\': 0.7734393}, {\'title\': \'Microsoft (MSFT) Market Cap & Net Worth - Stock Analysis\', \'url\': \'https://stockanalysis.com/stocks/msft/market-cap/\', \'content\': \'| Company | Market Cap |\\n --- |\\n| NVIDIA | 4.93T |\\n| Apple | 4.03T |\\n| Broadcom | 1.78T |\\n| Taiwan Semiconductor Manufacturing Company | 1.28T |\\n| Oracle | 732.34B |\\n| Pala ...
# exists_action =  False

# %%
result['messages'][-1].content
# Out:
# "Yes, Nvidia is currently more valuable than Microsoft. According to the search results, as of November 2025, Nvidia's market capitalization is approximately $4.920 - $5.113 trillion, while Microsoft's market cap is around $3.856 - $3.87 trillion."

# %%
# Note, the query was modified to produce more consistent results. 
# Results may vary per run and over time as search information and models change.

query = "What is Machine Learning" 
messages = [HumanMessage(content=query)]

# model = ChatOpenAI(model="gpt-4o")  # requires more advanced model
abot = AgentApp(model, [tool], system=prompt)
result = abot.graph.invoke({"messages": messages})
# Out:
# messages =  [HumanMessage(content='What is Machine Learning', additional_kwargs={}, response_metadata={})]
# exists_action =  True
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'machine learning definition and examples'}, 'id': '871912676', 'type': 'tool_call'}
# Back to the model!
# messages =  [HumanMessage(content='What is Machine Learning', additional_kwargs={}, response_metadata={}), AIMessage(content='Machine learning (ML) is a field of artificial intelligence (AI) that focuses on enabling systems to learn from data without being explicitly programmed. Instead of relying on pre-defined rules, ML algorithms identify patterns in data and use those patterns to make predictions or decisions.\n\n', additional_kwargs={'tool_calls': [{'id': '871912676', 'function': {'arguments': '{"query":"machine learning definition and examples"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 96, 'prompt_tokens': 563, 'total_tokens': 659, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'gemma-3-12b-it', 'system_fingerprint': 'gemma-3-12b-it', 'id': 'chatcmpl-cc708evhxio29f87kgr0ty', 'service_tier': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--3345904e-b9b6-45a3-b6dc-6a185c59b5b5-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'machine learning definition and examples'}, 'id': '871912676', 'type': 'tool_call'}], usage_metadata={'input_tokens': 563, 'output_tokens': 96, 'total_tokens': 659, 'input_token_details': {}, 'output_token_details': {}}), ToolMessage(content='[{\'title\': \'Real-World Examples of Machine Learning (ML) - Tableau\', \'url\': \'https://www.tableau.com/learn/articles/machine-learning-examples\', \'content\': \'learning; machine learning integration with radiology, cardiology, and pathology, for example, is leading to earlier detection of abnormalities or heightened attention on concerning areas. In the long run, machine learning will also benefit family practitioners or internists when treating patients bedside because data trends will predict health risks like heart disease. As an example, wearables generate mass amounts of data on the wearer’s health and many use AI and machine learning to alert [...] people and organizations are becoming more proactive and forward looking. Florida International University is one example. By integrating predictive models with data analysis from Tableau, they’re communicating critical insights about academic performance before students are at risk and supporting their individual needs to help them successfully complete all courses and graduate. [...] of some business operations and industries, and uncovering patterns that humans are likely to miss. Here are examples of machine learning at work in our daily life that provide value in many ways—some large and some small.\', \'score\': 0.73023266}, {\'title\': \'Machine learning, explained | MIT Sloan\', \'url\': \'https://mitsloan.mit.edu/ideas-made-to-matter/machine-learning-explained\', \'content\': \'What is machine learning?\\n\\nMachine learning is a subfield of artificial intelligence, which is broadly defined as the capability of a machine to imitate intelligent human behavior. Artificial intelligence systems are used to perform complex tasks in a way that is similar to how humans solve problems. [...] In the Work of the Future brief, Malone noted that machine learning is best suited for situations with lots of data — thousands or millions of examples, like recordings from previous conversations with customers, sensor logs from machines, or ATM transactions. For example, Google Translate was possible because it “trained” on the vast amount of information on the web, in different languages. [...] In some cases, machine learning models create or exacerbate social problems. For example, Facebook has used machine learning as a tool to show users ads and content that will interest and engage them —which has led to models showing people extreme content that leads to polarization and the spread of conspiracy theories when people are shown incendiary, partisan, or inaccurate content.\', \'score\': 0.7062922}, {\'title\': \'Machine Learning Examples, Applica ...
# exists_action =  False

# %%
print(result['messages'][-1].content)
# Out:
# Machine learning is a subfield of artificial intelligence where systems learn from data without explicit programming. It involves algorithms identifying patterns and using them for predictions or decisions.
#
# Here are some examples illustrating its use:
#
# *   **Healthcare:** Machine learning assists in early detection of abnormalities (radiology, cardiology, pathology) and predicting health risks like heart disease by analyzing patient data and wearable device information.
# *   **Education:** Predictive models analyze student performance to identify at-risk students and provide support.
# *   **Business:** It uncovers patterns in business operations and industries that humans might miss. Google Translate uses machine learning, having been "trained" on vast amounts of text in different languages.
# *   **Everyday Life:** Machine learning powers various applications we use daily, from personalized recommendations to fraud detection.

# %%
# Note, the query was modified to produce more consistent results. 
# Results may vary per run and over time as search information and models change.

query = "Which is the capital of India?" 
messages = [HumanMessage(content=query)]

# model = ChatOpenAI(model="gpt-4o")  # requires more advanced model
abot = AgentApp(model, [tool], system=prompt)
result = abot.graph.invoke({"messages": messages})
# Out:
# messages =  [HumanMessage(content='Which is the capital of India?', additional_kwargs={}, response_metadata={})]
# exists_action =  False

# %%
result["messages"][-1].content
# Out:
# 'New Delhi is the capital of India.'

# %% [markdown]
# ### Another example

# %%
# Note, the query was modified to produce more consistent results. 
# Results may vary per run and over time as search information and models change.

query = "Can you prove that a non deterministic finite automata (NFA) can be transformed to a deterministic finite automata (DFA)? Do not use any external tool." 
messages = [HumanMessage(content=query)]

# model = ChatOpenAI(model="gpt-4o")  # requires more advanced model
abot = AgentApp(model, [tool], system=prompt)
result = abot.graph.invoke({"messages": messages})
# Out:
# messages =  [HumanMessage(content='Can you prove that a non deterministic finite automata (NFA) can be transformed to a deterministic finite automata (DFA)? Do not use any external tool.', additional_kwargs={}, response_metadata={})]
# exists_action =  False

# %%
print(result['messages'][-1].content)
# Out:
# Yes, it is possible to transform an NFA into a DFA. This transformation is proven and well-established in the theory of computation. Here's a breakdown of the proof, often referred to as the "subset construction":
#
# **The Subset Construction Algorithm:**
#
# 1. **Initial State:** The initial state of the new DFA (D) is the ε-closure of the initial state of the NFA (N).  The ε-closure of a state includes all states reachable from that state via ε-transitions (transitions labeled with the empty string).
#
# 2. **Transition Function:** For each state *q* in the DFA and for each input symbol *a*:
#    * Find all states *p* in N such that there is a transition from *p* to some state *r* labeled *a*.  (In other words, find all states in N reachable from *p* via an 'a' transition).
#    * Compute the ε-closure of the set of all such states *r*. Let this set be denoted as *T*.
#    * The transition function δ<sub>D</sub>(*q*, *a*) is defined to be *T*.
#
# 3. **Final States:** A state in the DFA is a final state if it contains a final state from the NFA.  More formally, a state *q* in D is final if and only if there exists a state *p* in N such that *p* is a final state of N and *p* is contained within *q*.
#
# **Why this works (Proof Sketch):**
#
# The core idea is that each state in the DFA represents a *set* of states from the original NFA.  By taking the ε-closure, we account for all possible starting points within that set. The transition function then simulates all possible paths through the NFA for a given input symbol and collapses them into a single DFA state.
#
# **Why this proves transformation:**
#
# *   The subset construction algorithm provides a clear procedure to build a DFA from an NFA.
# *   It guarantees that the resulting DFA accepts the same language as the original NFA.  This is because every string accepted by the NFA will be accepted by the DFA (since the DFA simulates all possible paths of the NFA), and vice versa (every string accepted by the DFA must have been accepted by at least one path in the NFA).
# *   The construction is deterministic; it provides a well-defined transition for each state and input symbol in the DFA.
#
# **Important Notes:**
#
# *   The resulting DFA can be exponentially larger than the original NFA (in terms of the number of states). This is because a single DFA state represents a *set* of NFA states.
# *   While the transformation is guaranteed, it can be computationally expensive for large NFAs.
#
#
#
# I have provided the proof without using any external tools as requested.

# %% [markdown]
# ### Tighter Prompt

# %%
prompt1 = """
You are a highly capable and knowledgeable research assistant.
Answer user questions directly using your own knowledge whenever possible.

Only use the search tool when you are genuinely uncertain or when the information is likely to be time-sensitive, future-dated, highly specific, or obscure.

Do not use the search tool for well-known, general knowledge questions. Examples include definitions, concepts, widely-known facts, or questions about known topics 

Search is expensive. Avoid unnecessary searches.

You may make multiple searches if needed, but only after carefully considering whether it is necessary.

🔔 When to search:
✅ Questions about future events
✅ Current news, prices, recent changes
✅ Specific or uncommon details you’re unsure about
✅ Things you know require recent verification

🚫 When NOT to search:
❌ General knowledge you already understand
❌ Definitions of common concepts
❌ Facts you are confident about

🔑 Important Instruction:
If you know the answer confidently, answer immediately. Do not invoke the search tool.

If you are unsure, think through the question step-by-step before deciding whether to search.

"""

# %%
query = "Who won the womens world cup finals cricket match last weekend?" 
messages = [HumanMessage(content=query)]

# model = ChatOpenAI(model="gpt-4o")  # requires more advanced model
abot = AgentApp(model, [tool], system=prompt1)
result = abot.graph.invoke({"messages": messages})
# Out:
# messages =  [HumanMessage(content='Who won the womens world cup finals cricket match last weekend?', additional_kwargs={}, response_metadata={})]
# exists_action =  True
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'womens cricket world cup final result last weekend'}, 'id': '142508400', 'type': 'tool_call'}
# Back to the model!
# messages =  [HumanMessage(content='Who won the womens world cup finals cricket match last weekend?', additional_kwargs={}, response_metadata={}), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': '142508400', 'function': {'arguments': '{"query":"womens cricket world cup final result last weekend"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 44, 'prompt_tokens': 674, 'total_tokens': 718, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'gemma-3-12b-it', 'system_fingerprint': 'gemma-3-12b-it', 'id': 'chatcmpl-l6gyord44hllkarecoke7', 'service_tier': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--200424cb-ba77-41fd-b7b4-1a72ebc50f61-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'womens cricket world cup final result last weekend'}, 'id': '142508400', 'type': 'tool_call'}], usage_metadata={'input_tokens': 674, 'output_tokens': 44, 'total_tokens': 718, 'input_token_details': {}, 'output_token_details': {}}), ToolMessage(content='[{\'title\': "2025 Women\'s Cricket World Cup - Wikipedia", \'url\': \'https://en.wikipedia.org/wiki/2025_Women%27s_Cricket_World_Cup\', \'content\': \'25 September 2025 \\n\\n15:00 (D/N) \\n\\nScorecard\\n\\nEnglandImage 58: England\\n\\n340/9 (50 overs)vImage 59India\\n\\n187 (34 overs)\\nNat Sciver-Brunt 120 (104) \\n\\nKranti Goud 3/31 (5 overs)Jemimah Rodrigues 66 (68) \\n\\nLinsey Smith 2/35 (6 overs)\\n\\nEngland won by 153 runs\\n\\n BCCI Centre of Excellence Ground A, Bengaluru\\n\\nUmpires: Sarah Dambanevana (Zim) and Eloise Sheridan (Aus)\\n\\n   India won the toss and elected to field. \\n\\n  \\n\\n27 September 2025 \\n\\n15:00 (D/N) \\n\\nScorecard\\n\\nBangladeshImage 60 [...] | Score | Player | 4s | 6s | SR | Against | Venue | Date |\\n ---  ---  ---  --- |\\n| 169 (143) | Image 171: South AfricaLaura Wolvaardt | 20 | 4 | 118.18 | Image 172: EnglandEngland | Guwahati | 29 October 2025 |\\n| 142 (107) | Image 173: AustraliaAlyssa Healy | 21 | 3 | 132.71 | Image 174India | Visakhapatnam | 12 October 2025 |\\n| 127 (134) | Image 175: IndiaJemimah Rodrigues | 14 | 0 | 94.78 | Image 176Australia | Navi Mumbai | 30 October 2025 | [...] Umpires: Kim Cotton (NZ) and Nimali Perera (SL)\\n\\n   South Africa won the toss and elected to bat.\\n   No further play was possible due to rain. \\n\\n  \\n\\n25 September 2025 \\n\\n15:00 (D/N) \\n\\nScorecard\\n\\nSri LankaImage 56\\n\\n33/1 (7.3 overs)vImage 57Pakistan\\nHasini Perera 21 (28) \\n\\nFatima Sana 1/21 (4 overs)\\n\\nNo result\\n\\nColombo Cricket Club Ground, Colombo\\n\\nUmpires: Lauren Agenbag (SA) and Kerrin Klaaste (SA)\\n\\n   Sri Lanka won the toss and elected to bat.\\n   No further play was possible due to rain.\', \'score\': 0.80771893}, {\'title\': "Women\'s Cricket World Cup: India wins for first time, beating ... - CNN", \'url\': \'https://www.cnn.com/2025/11/02/sport/india-cricket-womenn-world-cup-intl-hnk\', \'content\': "India\'s players celebrate their win over South Africa in the ICC Women\'s Cricket World Cup final match in Navi Mumbai, India on November 3, 2025.\\n\\nRafiq Maqbool/AP\\n\\nIndia Asia Africa Soccer\\n\\nSee all topics\\n\\nFacebook TweetEmailLink\\n\\n Link Copied! \\n\\nIndia won the Women’s Cricket World Cup for the first time with a 52-run victory over South Africa on Sunday, led by brilliant all-round performances from Deepti Sharma and Shafali Verma. [...] India\'s captain Harmanpreet Kaur, left, and India\'s Deepti Sharma celebrate the dismissal of South Africa\'s captain Laura Wolvaardt during the ICC Women\'s Cricket World Cup final match between India and South Africa in Navi Mumbai, India on November 2, 2025.\\n\\nRafiq Maqbool/AP\\n\\nPlayer of the match\\n\\nVerma - who was drafted in last week for the injured Pratika Rawal - took 2-36 with the ball and was voted player of the match. [...] Image 3: Indian players celebrat ...
# exists_action =  False

# %%
print(result['messages'][-1].content)
# Out:
# India won the Women's Cricket World Cup final against South Africa on November 2, 2025, by 52 runs.

# %%
# Out:
# Object `weekend` not found.
